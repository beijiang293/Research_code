# %% [markdown]
# Setup enviroment

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.2.0+cu121

# %%
# !pip install -q dgl

# %%
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid
from torch_geometric import nn
import torch_geometric.transforms as T
# Out:
# /home/yc774/.conda/envs/gnn/lib/python3.10/site-packages/torch_geometric/typing.py:63: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /vast/palmer/home.mccleary/yc774/.conda/envs/gnn/lib/python3.10/site-packages/torch_scatter/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/yc774/.conda/envs/gnn/lib/python3.10/site-packages/torch_geometric/typing.py:101: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /vast/palmer/home.mccleary/yc774/.conda/envs/gnn/lib/python3.10/site-packages/torch_sparse/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
import json
import pandas as pd
import numpy as np
import random
import dgl
import dgl.nn as dglnn
import torch.nn as nn
import torch.nn.functional as F
import dgl.function as fn
# Out:
# /tmp/ipykernel_3623614/4213285088.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Load node2id dictionary

# %%
os.path.isdir("/gpfs/gibbs/pi/gerstein/yc774/project/miRGD/graph")
# Out:
# True

# %%
#open files
proj_dir = os.path.join("/gpfs/gibbs/pi/gerstein/yc774/project/miRGD/graph")
f = open(os.path.join(proj_dir,"node2id.json"))
node2id = json.load(f)

f = open(os.path.join(proj_dir,"id2node.json"))
id2node = json.load(f)

# %%
relation = ["mm","dd","gg","md","mg","dg"]

edge_index = {}
for rel in relation:
  pth = os.path.join(proj_dir,"{}_edge.csv".format(rel))
  edge_df = pd.read_csv(pth)
  edge_list = np.transpose(edge_df.values)
  edge_index[rel] = torch.tensor(edge_list).long()

# %%
edge_index
# Out:
# {'mm': tensor([[ 898,  898,  898,  ...,  694,  482,  482],
#          [ 841, 1069,  541,  ...,  953, 1011,  147]]),
#  'dd': tensor([[1175, 1175, 1175,  ..., 1134, 1134, 1134],
#          [1180, 1144, 1208,  ..., 1168, 1141, 1139]]),
#  'gg': tensor([[2147, 2147, 2147,  ..., 6556, 8910, 5385],
#          [8388, 7092, 9807,  ..., 1735, 1735, 1735]]),
#  'md': tensor([[ 898,  898,  898,  ...,  270,  946,  250],
#          [1193, 1180, 1214,  ..., 1191, 1213, 1213]]),
#  'mg': tensor([[  32,  832,  832,  ...,  589,  589,  100],
#          [5215, 7835, 7835,  ..., 5135, 9328, 4016]]),
#  'dg': tensor([[5925, 5925, 4194,  ..., 7342, 5467, 5467],
#          [1183, 1153, 1153,  ..., 1204, 1131, 1148]])}

# %%
miRNA_id = list(range(1109))
disease_id = list(range(1109,1222))
gene_id = list(range(1222,10532))


# convert old unique id to seperete set of new ID
disease_new_id_dict = {}
new_id = 0
for old_id in disease_id:
  disease_new_id_dict[old_id] = new_id
  new_id+=1

gene_new_id_dict = {}
new_id = 0
for old_id in gene_id:
  gene_new_id_dict[old_id] = new_id
  new_id+=1



new_edge_index = {}
new_edge_index['mm'] = edge_index['mm']

new_edge_index['dd'] = torch.tensor([
  [disease_new_id_dict[old_id] for old_id in edge_index['dd'][0].numpy()],
  [disease_new_id_dict[old_id] for old_id in edge_index['dd'][1].numpy()],
])
new_edge_index['gg'] = torch.tensor([
  [gene_new_id_dict[old_id] for old_id in edge_index['gg'][0].numpy()],
  [gene_new_id_dict[old_id] for old_id in edge_index['gg'][1].numpy()],
])
new_edge_index['md'] = torch.tensor([
  edge_index['md'][0].numpy(),
  [disease_new_id_dict[old_id] for old_id in edge_index['md'][1].numpy()],
])

new_edge_index['mg'] = torch.tensor([
  edge_index['mg'][0].numpy(),
  [gene_new_id_dict[old_id] for old_id in edge_index['mg'][1].numpy()]
])

new_edge_index['gd'] = torch.tensor([
  [gene_new_id_dict[old_id] for old_id in edge_index['dg'][0].numpy()],
  [disease_new_id_dict[old_id] for old_id in edge_index['dg'][1].numpy()],
])
# Out:
# /tmp/ipykernel_3623614/2437488178.py:32: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:275.)
#   new_edge_index['md'] = torch.tensor([

# %%
new_edge_index
# Out:
# {'mm': tensor([[ 898,  898,  898,  ...,  694,  482,  482],
#          [ 841, 1069,  541,  ...,  953, 1011,  147]]),
#  'dd': tensor([[66, 66, 66,  ..., 25, 25, 25],
#          [71, 35, 99,  ..., 59, 32, 30]]),
#  'gg': tensor([[ 925,  925,  925,  ..., 5334, 7688, 4163],
#          [7166, 5870, 8585,  ...,  513,  513,  513]]),
#  'md': tensor([[898, 898, 898,  ..., 270, 946, 250],
#          [ 84,  71, 105,  ...,  82, 104, 104]]),
#  'mg': tensor([[  32,  832,  832,  ...,  589,  589,  100],
#          [3993, 6613, 6613,  ..., 3913, 8106, 2794]]),
#  'gd': tensor([[4703, 4703, 2972,  ..., 6120, 4245, 4245],
#          [  74,   44,   44,  ...,   95,   22,   39]])}

# %%
n_hetero_features = 10

hetero_graph = dgl.heterograph({
    ('miRNA', 'similar_to', 'miRNA'): (new_edge_index['mm'][0], new_edge_index['mm'][1]),
    ('gene', 'similar_to', 'gene'): (new_edge_index['gg'][0], new_edge_index['gg'][1]),
    ('disease', 'similar_to', 'disease'): (new_edge_index['dd'][0], new_edge_index['dd'][1]),
    ('miRNA', 'target_to', 'gene'): (new_edge_index['mg'][0], new_edge_index['mg'][1]),
    ('miRNA', 'associate_with', 'disease'): (new_edge_index['md'][0], new_edge_index['md'][1]),
    ('gene', 'related_to', 'disease'): (new_edge_index['gd'][0], new_edge_index['gd'][1])})

n_miRNA = hetero_graph.num_nodes('miRNA')
n_gene = hetero_graph.num_nodes('gene')
n_disease= hetero_graph.num_nodes('disease')

hetero_graph.nodes['miRNA'].data['feature'] = torch.randn(n_miRNA, n_hetero_features)
hetero_graph.nodes['gene'].data['feature'] = torch.randn(n_gene, n_hetero_features)
hetero_graph.nodes['disease'].data['feature'] = torch.randn(n_disease, n_hetero_features)

hetero_graph
# Out:
# Graph(num_nodes={'disease': 113, 'gene': 9308, 'miRNA': 1109},
#       num_edges={('disease', 'similar_to', 'disease'): 4863, ('gene', 'related_to', 'disease'): 9596, ('gene', 'similar_to', 'gene'): 519568, ('miRNA', 'associate_with', 'disease'): 3999, ('miRNA', 'similar_to', 'miRNA'): 346623, ('miRNA', 'target_to', 'gene'): 25405},
#       metagraph=[('disease', 'disease', 'similar_to'), ('gene', 'disease', 'related_to'), ('gene', 'gene', 'similar_to'), ('miRNA', 'disease', 'associate_with'), ('miRNA', 'miRNA', 'similar_to'), ('miRNA', 'gene', 'target_to')])

# %%
hetero_graph.nodes['miRNA']
# Out:
# NodeSpace(data={'feature': tensor([[ 0.0926,  0.5273,  1.3350,  ...,  1.2949,  0.8614, -0.2575],
#         [ 0.2802, -1.9979, -1.3191,  ...,  1.1922, -0.2682, -1.2076],
#         [-0.0251,  1.0422,  0.6081,  ...,  0.3608, -0.4745, -0.4901],
#         ...,
#         [ 0.3069,  0.2247,  0.8623,  ..., -0.3226, -1.8404, -1.6016],
#         [-0.8004, -1.4858,  1.6648,  ...,  0.7354,  0.0896, -1.4619],
#         [-0.2223,  2.1783, -1.1702,  ..., -1.1988, -0.0681,  0.6123]])})

# %% [markdown]
# Link Prediction - Random Feature

# %%
class HeteroGAT_2layer(nn.Module):
    def __init__(self, in_feats, hid_feats, out_feats, rel_names, num_heads=8):
        super().__init__()

        # First GAT layer for each relation
        self.conv1 = dglnn.HeteroGraphConv({
            rel: dglnn.GATConv(in_feats, hid_feats, num_heads=num_heads)
            for rel in rel_names}, aggregate='mean')

        # Adjust in_feats for second layer considering num_heads
        self.conv2 = dglnn.HeteroGraphConv({
            rel: dglnn.GATConv(hid_feats * num_heads, out_feats, num_heads=num_heads)
            for rel in rel_names}, aggregate='mean')

    def forward(self, graph, inputs, mask=None):
        # First layer
        h = self.conv1(graph, inputs)
        # Apply non-linearity and concatenate heads
        h = {k: F.relu(v).view(v.shape[0], -1) for k, v in h.items()}

        # Second layer
        h = self.conv2(graph, h)
        # Concatenate heads for output layer as well
        h = {k: v.view(v.shape[0], -1) for k, v in h.items()}

        return h

def construct_negative_graph(graph, k, etype):
    utype, _, vtype = etype
    src, dst = graph.edges(etype=etype)
    neg_src = src.repeat_interleave(k)
    neg_dst = torch.randint(0, graph.num_nodes(vtype), (len(src) * k,))
    return dgl.heterograph(
        {etype: (neg_src, neg_dst)},
        num_nodes_dict={ntype: graph.num_nodes(ntype) for ntype in graph.ntypes})

class HeteroDotProductPredictor(nn.Module):
    def forward(self, graph, h, etype):
        # h contains the node representations for each node type computed from
        # the GNN defined in the previous section (Section 5.1).
        with graph.local_scope():
            graph.ndata['h'] = h
            graph.apply_edges(fn.u_dot_v('h', 'h', 'score'), etype=etype)
            return graph.edges[etype].data['score']

class Model(nn.Module):
    def __init__(self, in_features, hidden_features, out_features, rel_names):
        super().__init__()
        self.sage = HeteroGAT_2layer(in_features, hidden_features, out_features, rel_names)
        self.pred = HeteroDotProductPredictor()
    def forward(self, g, neg_g, x, etype, pos_train_mask):
        h = self.sage(g, x, pos_train_mask)
        return self.pred(g, h, etype), self.pred(neg_g, h, etype)


n_hetero_features = 32
n_hidden = 64
n_output = 32
hetero_graph = dgl.heterograph({
    ('miRNA', 'similar_to', 'miRNA'): (new_edge_index['mm'][0], new_edge_index['mm'][1]),
    ('gene', 'similar_to', 'gene'): (new_edge_index['gg'][0], new_edge_index['gg'][1]),
    ('disease', 'similar_to', 'disease'): (new_edge_index['dd'][0], new_edge_index['dd'][1]),
    ('miRNA', 'target_to', 'gene'): (new_edge_index['mg'][0], new_edge_index['mg'][1]),
    ('miRNA', 'associate_with', 'disease'): (new_edge_index['md'][0], new_edge_index['md'][1]),
    ('gene', 'related_to', 'disease'): (new_edge_index['gd'][0], new_edge_index['gd'][1])})

n_miRNA = hetero_graph.num_nodes('miRNA')
n_gene = hetero_graph.num_nodes('gene')
n_disease= hetero_graph.num_nodes('disease')

hetero_graph.nodes['miRNA'].data['feature'] = torch.randn(n_miRNA, n_hetero_features)
hetero_graph.nodes['gene'].data['feature'] = torch.randn(n_gene, n_hetero_features)
hetero_graph.nodes['disease'].data['feature'] = torch.randn(n_disease, n_hetero_features)

def compute_loss_with_mask(pos_score, neg_score):
    # Margin loss
    n_edges = pos_score.shape[0]
    return (1 - pos_score +  neg_score.view(n_edges, -1)).clamp(min=0).mean()


k = 5
model = Model(n_hetero_features, n_hidden, n_output, hetero_graph.etypes)
miRNA_feats = hetero_graph.nodes['miRNA'].data['feature']
gene_feats = hetero_graph.nodes['gene'].data['feature']
disease_feats = hetero_graph.nodes['disease'].data['feature']
node_features = {'miRNA': miRNA_feats, 'gene': gene_feats, 'disease':disease_feats}

num_target_edge = hetero_graph['associate_with'].num_edges()
pos_train_mask = (torch.rand(num_target_edge, 1) > 0.3).float()

pos_train_index = torch.tensor(np.where(pos_train_mask == 1)[0])
pos_valid_index = torch.tensor(np.where(pos_train_mask == 0)[0])

train_loss_accu = []
valid_loss_accu = []

train_accuracy_accu = []
valid_accuracy__accu = []

num_epoch = 200

loss_fn = nn.BCEWithLogitsLoss()

opt = torch.optim.Adam(model.parameters())
for epoch in range(num_epoch):
    negative_graph_train = construct_negative_graph(hetero_graph, k, ('miRNA', 'associate_with', 'disease'))
    pos_score, neg_score = model(hetero_graph, negative_graph_train, node_features, ('miRNA', 'associate_with', 'disease'),pos_train_mask)

    perm = torch.randperm(neg_score.size(0))
    neg_train_index = perm[:int(5*sum(pos_train_mask))]
    neg_valid_index = perm[int(5*sum(pos_train_mask)):]

    loss = compute_loss_with_mask(torch.index_select(pos_score, 0, pos_train_index),torch.index_select(neg_score, 0, neg_train_index))

    predict = torch.cat((torch.index_select(pos_score, 0, pos_train_index),torch.index_select(neg_score, 0, neg_train_index)),0)
    target = torch.tensor([1]*torch.index_select(pos_score, 0, pos_train_index).shape[0] + [0]*torch.index_select(neg_score, 0, neg_train_index).shape[0]).unsqueeze(1)
    #target = target.to(device)

    loss = loss_fn(predict, target.float())

    opt.zero_grad()
    loss.backward()
    opt.step()


    predict = torch.cat((torch.index_select(pos_score, 0, pos_valid_index),torch.index_select(neg_score, 0, neg_valid_index)),0)
    target = torch.tensor([1]*torch.index_select(pos_score, 0, pos_valid_index).shape[0] + [0]*torch.index_select(neg_score, 0, neg_valid_index).shape[0]).unsqueeze(1)
    #target = target.to(device)
    valid_loss = loss_fn(predict, target.float())


    train_loss_accu.append(loss.item())
    valid_loss_accu.append(valid_loss.item())

    accu_pos = (torch.index_select(pos_score, 0, pos_valid_index) > 0)
    accu_neg = (torch.index_select(neg_score, 0, neg_valid_index) < 0)
    valid_accu = (sum(accu_pos)+sum(accu_neg))/(len(accu_pos)+len(accu_neg))

    accu_pos = (torch.index_select(pos_score, 0, pos_train_index) > 0)
    accu_neg = (torch.index_select(neg_score, 0, neg_train_index) < 0)
    train_accu = (sum(accu_pos)+sum(accu_neg))/(len(accu_pos)+len(accu_neg))

    train_accuracy_accu.append(train_accu)
    valid_accuracy__accu.append(valid_accu)

    print("epoch: ", epoch, " train loss: ", loss.item(), " valid loss: ",valid_loss.item(), " train_accuracy: ",train_accu," valid accuracy: ",valid_accu)
# Out:
# epoch:  0  train loss:  0.7356882095336914  valid loss:  0.7349564433097839  train_accuracy:  tensor([0.1521])  valid accuracy:  tensor([0.1518])
# epoch:  1  train loss:  0.6879496574401855  valid loss:  0.6881986856460571  train_accuracy:  tensor([0.7104])  valid accuracy:  tensor([0.7009])
# epoch:  2  train loss:  0.6606143116950989  valid loss:  0.6610071063041687  train_accuracy:  tensor([0.8267])  valid accuracy:  tensor([0.8278])
# epoch:  3  train loss:  0.6372523307800293  valid loss:  0.6373082399368286  train_accuracy:  tensor([0.8294])  valid accuracy:  tensor([0.8294])
# epoch:  4  train loss:  0.6098342537879944  valid loss:  0.6111752986907959  train_accuracy:  tensor([0.8306])  valid accuracy:  tensor([0.8305])
# epoch:  5  train loss:  0.5776740312576294  valid loss:  0.5783838629722595  train_accuracy:  tensor([0.8316])  valid accuracy:  tensor([0.8306])
# epoch:  6  train loss:  0.5414363145828247  valid loss:  0.541613757610321  train_accuracy:  tensor([0.8316])  valid accuracy:  tensor([0.8316])
# epoch:  7  train loss:  0.5089911818504333  valid loss:  0.5118110775947571  train_accuracy:  tensor([0.8320])  valid accuracy:  tensor([0.8309])
# epoch:  8  train loss:  0.49248766899108887  valid loss:  0.49412330985069275  train_accuracy:  tensor([0.8320])  valid accuracy:  tensor([0.8314])
# epoch:  9  train loss:  0.49863314628601074  valid loss:  0.5060856342315674  train_accuracy:  tensor([0.8322])  valid accuracy:  tensor([0.8314])
# epoch:  10  train loss:  0.5174806714057922  valid loss:  0.5239772796630859  train_accuracy:  tensor([0.8328])  valid accuracy:  tensor([0.8324])
# epoch:  11  train loss:  0.5239596962928772  valid loss:  0.5257189273834229  train_accuracy:  tensor([0.8327])  valid accuracy:  tensor([0.8325])
# epoch:  12  train loss:  0.5137547254562378  valid loss:  0.5171049237251282  train_accuracy:  tensor([0.8329])  valid accuracy:  tensor([0.8323])
# epoch:  13  train loss:  0.4983656704425812  valid loss:  0.4999903738498688  train_accuracy:  tensor([0.8325])  valid accuracy:  tensor([0.8325])
# epoch:  14  train loss:  0.48536986112594604  valid loss:  0.486166387796402  train_accuracy:  tensor([0.8327])  valid accuracy:  tensor([0.8324])
# epoch:  15  train loss:  0.4793621897697449  valid loss:  0.4799341857433319  train_accuracy:  tensor([0.8329])  valid accuracy:  tensor([0.8320])
# epoch:  16  train loss:  0.4779950678348541  valid loss:  0.4834292232990265  train_accuracy:  tensor([0.8326])  valid accuracy:  tensor([0.8308])
# epoch:  17  train loss:  0.48389187455177307  valid loss:  0.48375198245048523  train_accuracy:  tensor([0.8322])  valid accuracy:  tensor([0.8316])
# epoch:  18  train loss:  0.48412442207336426  valid loss:  0.4860231280326843  train_accuracy:  tensor([0.8325])  valid accuracy:  tensor([0.8320])
# epoch:  19  train loss:  0.48386839032173157  valid loss:  0.48474085330963135  train_accuracy:  tensor([0.8330])  valid accuracy:  tensor([0.8332])
# epoch:  20  train loss:  0.48103469610214233  valid loss:  0.4817218780517578  train_accuracy:  tensor([0.8330])  valid accuracy:  tensor([0.8331])
# epoch:  21  train loss:  0.47689104080200195  valid loss:  0.4790477454662323  train_accuracy:  tensor([0.8330])  valid accuracy:  tensor([0.8331])
# epoch:  22  train loss:  0.4715307950973511  valid loss:  0.4728281497955322  train_accuracy:  tensor([0.8329])  valid accuracy:  tensor([0.8332])
# epoch:  23  train loss:  0.46722114086151123  valid loss:  0.47072634100914  train_accuracy:  tensor([0.8330])  valid accuracy:  tensor([0.8331])
# epoch:  24  train loss:  0.4650475084781647  valid loss:  0.4671393930912018  train_accuracy:  tensor([0.8330])  valid accuracy:  tensor([0.8331])
# epoch:  25  train loss:  0.46384936571121216  valid loss:  0.4665658175945282  train_accuracy:  tensor([0.8330])  valid accuracy:  tensor([0.8331])
# epoch:  26  train loss:  0.4643312990665436  valid loss:  0.463742196559906  train_accuracy:  tensor([0.8332])  valid accuracy:  tensor([0.8329])
# epoch:  27  train loss:  0.4625665843486786  valid loss:  0.465434193611145  train_accuracy:  tensor([0.8332])  valid accuracy:  tensor([0.8328])
# epoch:  28  train loss:  0.46090760827064514  valid loss:  0.46485790610313416  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8327])
# epoch:  29  train loss:  0.45780453085899353  valid loss:  0.46344903111457825  train_accuracy:  tensor([0.8328])  valid accuracy:  tensor([0.8327])
# epoch:  30  train loss:  0.45564937591552734  valid loss:  0.45852893590927124  train_accuracy:  tensor([0.8331])  valid accuracy:  tensor([0.8323])
# epoch:  31  train loss:  0.4527297616004944  valid loss:  0.4559571146965027  train_accuracy:  tensor([0.8329])  valid accuracy:  tensor([0.8323])
# epoch:  32  train loss:  0.44985154271125793  valid loss:  0.45360225439071655  train_accuracy:  tensor([0.8327])  valid accuracy:  tensor([0.8328])
# epoch:  33  train loss:  0.4483734965324402  valid loss:  0.45157548785209656  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8329])
# epoch:  34  train loss:  0.4482477903366089  valid loss:  0.4474393129348755  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8332])
# epoch:  35  train loss:  0.4450716972351074  valid loss:  0.44796252250671387  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8332])
# epoch:  36  train loss:  0.4453504979610443  valid loss:  0.44600921869277954  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8333])
# epoch:  37  train loss:  0.4438430964946747  valid loss:  0.44546782970428467  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8333])
# epoch:  38  train loss:  0.4405093491077423  valid loss:  0.4424000680446625  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8333])
# epoch:  39  train loss:  0.43988287448883057  valid loss:  0.437818318605423  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8333])
# epoch:  40  train loss:  0.4364396929740906  valid loss:  0.4373186230659485  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8333])
# epoch:  41  train loss:  0.43493708968162537  valid loss:  0.43693092465400696  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8333])
# epoch:  42  train loss:  0.43327441811561584  valid loss:  0.43366071581840515  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8333])
# epoch:  43  train loss:  0.430580735206604  valid loss:  0.43295085430145264  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8331])
# epoch:  44  train loss:  0.42795529961586  valid loss:  0.4316644072532654  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8333])
# epoch:  45  train loss:  0.42452141642570496  valid loss:  0.4256281852722168  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8332])
# epoch:  46  train loss:  0.42313218116760254  valid loss:  0.4260004460811615  train_accuracy:  tensor([0.8333])  valid accuracy:  tensor([0.8333])
# epoch:  47  train loss:  0.42168140411376953  valid loss:  0.42294374108314514  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8333])
# epoch:  48  train loss:  0.4184493124485016  valid loss:  0.4211645722389221  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8329])
# epoch:  49  train loss:  0.41646501421928406  valid loss:  0.41900378465652466  train_accuracy:  tensor([0.8336])  valid accuracy:  tensor([0.8333])
# epoch:  50  train loss:  0.4144843518733978  valid loss:  0.4140077531337738  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8332])
# epoch:  51  train loss:  0.4104786813259125  valid loss:  0.413857638835907  train_accuracy:  tensor([0.8336])  valid accuracy:  tensor([0.8335])
# epoch:  52  train loss:  0.40962618589401245  valid loss:  0.4128625988960266  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8335])
# epoch:  53  train loss:  0.40898242592811584  valid loss:  0.40887969732284546  train_accuracy:  tensor([0.8334])  valid accuracy:  tensor([0.8332])
# epoch:  54  train loss:  0.4072568118572235  valid loss:  0.4087350368499756  train_accuracy:  tensor([0.8337])  valid accuracy:  tensor([0.8332])
# epoch:  55  train loss:  0.4052451252937317  valid loss:  0.4064747095108032  train_accuracy:  tensor([0.8338])  valid accuracy:  tensor([0.8328])
# epoch:  56  train loss:  0.4049258828163147  valid loss:  0.40431639552116394  train_accuracy:  tensor([0.8341])  valid accuracy:  tensor([0.8354])
# epoch:  57  train loss:  0.39999255537986755  valid loss:  0.40037697553634644  train_accuracy:  tensor([0.8342])  valid accuracy:  tensor([0.8362])
# epoch:  58  train loss:  0.402227520942688  valid loss:  0.3972158133983612  train_accuracy:  tensor([0.8320])  valid accuracy:  tensor([0.8352])
# epoch:  59  train loss:  0.3982631266117096  valid loss:  0.393528014421463  train_accuracy:  tensor([0.8347])  valid accuracy:  tensor([0.8359])
# epoch:  60  train loss:  0.3946642577648163  valid loss:  0.3935874402523041  train_accuracy:  tensor([0.8345])  valid accuracy:  tensor([0.8354])
# epoch:  61  train loss:  0.3923509418964386  valid loss:  0.39283114671707153  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8356])
# epoch:  62  train loss:  0.3890279531478882  valid loss:  0.38962286710739136  train_accuracy:  tensor([0.8338])  valid accuracy:  tensor([0.8356])
# epoch:  63  train loss:  0.38715770840644836  valid loss:  0.3852559030056  train_accuracy:  tensor([0.8318])  valid accuracy:  tensor([0.8340])
# epoch:  64  train loss:  0.38619765639305115  valid loss:  0.3840391933917999  train_accuracy:  tensor([0.8350])  valid accuracy:  tensor([0.8372])
# epoch:  65  train loss:  0.38068753480911255  valid loss:  0.3820805251598358  train_accuracy:  tensor([0.8364])  valid accuracy:  tensor([0.8383])
# epoch:  66  train loss:  0.38250309228897095  valid loss:  0.38036033511161804  train_accuracy:  tensor([0.8335])  valid accuracy:  tensor([0.8370])
# epoch:  67  train loss:  0.3797057271003723  valid loss:  0.3763994574546814  train_accuracy:  tensor([0.8345])  valid accuracy:  tensor([0.8360])
# epoch:  68  train loss:  0.3788408935070038  valid loss:  0.3727497160434723  train_accuracy:  tensor([0.8329])  valid accuracy:  tensor([0.8363])
# epoch:  69  train loss:  0.3752531409263611  valid loss:  0.3753020465373993  train_accuracy:  tensor([0.8360])  valid accuracy:  tensor([0.8406])
# epoch:  70  train loss:  0.37578916549682617  valid loss:  0.370975136756897  train_accuracy:  tensor([0.8390])  valid accuracy:  tensor([0.8374])
# epoch:  71  train loss:  0.37199947237968445  valid loss:  0.3716356158256531  train_accuracy:  tensor([0.8377])  valid accuracy:  tensor([0.8374])
# epoch:  72  train loss:  0.37183424830436707  valid loss:  0.3720510005950928  train_accuracy:  tensor([0.8374])  valid accuracy:  tensor([0.8389])
# epoch:  73  train loss:  0.37394529581069946  valid loss:  0.3691483438014984  train_accuracy:  tensor([0.8359])  valid accuracy:  tensor([0.8370])
# epoch:  74  train loss:  0.3703029453754425  valid loss:  0.3687248229980469  train_accuracy:  tensor([0.8332])  valid accuracy:  tensor([0.8356])
# epoch:  75  train loss:  0.36752602458000183  valid loss:  0.36868607997894287  train_accuracy:  tensor([0.8386])  valid accuracy:  tensor([0.8386])
# epoch:  76  train loss:  0.36747968196868896  valid loss:  0.36717310547828674  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8448])
# epoch:  77  train loss:  0.36860162019729614  valid loss:  0.36639782786369324  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8403])
# epoch:  78  train loss:  0.36745578050613403  valid loss:  0.3652143180370331  train_accuracy:  tensor([0.8396])  valid accuracy:  tensor([0.8409])
# epoch:  79  train loss:  0.36648276448249817  valid loss:  0.36490991711616516  train_accuracy:  tensor([0.8375])  valid accuracy:  tensor([0.8380])
# epoch:  80  train loss:  0.3661804497241974  valid loss:  0.36328354477882385  train_accuracy:  tensor([0.8401])  valid accuracy:  tensor([0.8407])
# epoch:  81  train loss:  0.3651447296142578  valid loss:  0.3644557595252991  train_accuracy:  tensor([0.8390])  valid accuracy:  tensor([0.8441])
# epoch:  82  train loss:  0.3643607199192047  valid loss:  0.3644362688064575  train_accuracy:  tensor([0.8388])  valid accuracy:  tensor([0.8416])
# epoch:  83  train loss:  0.36435261368751526  valid loss:  0.3626317083835602  train_accuracy:  tensor([0.8369])  valid accuracy:  tensor([0.8385])
# epoch:  84  train loss:  0.36244070529937744  valid loss:  0.3607948124408722  train_accuracy:  tensor([0.8388])  valid accuracy:  tensor([0.8394])
# epoch:  85  train loss:  0.36244362592697144  valid loss:  0.36139318346977234  train_accuracy:  tensor([0.8398])  valid accuracy:  tensor([0.8399])
# epoch:  86  train loss:  0.3614876866340637  valid loss:  0.35764554142951965  train_accuracy:  tensor([0.8416])  valid accuracy:  tensor([0.8438])
# epoch:  87  train loss:  0.36126944422721863  valid loss:  0.36025384068489075  train_accuracy:  tensor([0.8387])  valid accuracy:  tensor([0.8387])
# epoch:  88  train loss:  0.3612547516822815  valid loss:  0.3561769723892212  train_accuracy:  tensor([0.8382])  valid accuracy:  tensor([0.8425])
# epoch:  89  train loss:  0.3598618507385254  valid loss:  0.3558368980884552  train_accuracy:  tensor([0.8420])  valid accuracy:  tensor([0.8444])
# epoch:  90  train loss:  0.35950595140457153  valid loss:  0.35644954442977905  train_accuracy:  tensor([0.8400])  valid accuracy:  tensor([0.8468])
# epoch:  91  train loss:  0.36013033986091614  valid loss:  0.35768985748291016  train_accuracy:  tensor([0.8406])  valid accuracy:  tensor([0.8436])
# epoch:  92  train loss:  0.35836321115493774  valid loss:  0.35603195428848267  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8464])
# epoch:  93  train loss:  0.35770002007484436  valid loss:  0.3574293553829193  train_accuracy:  tensor([0.8425])  valid accuracy:  tensor([0.8449])
# epoch:  94  train loss:  0.3571417033672333  valid loss:  0.356705904006958  train_accuracy:  tensor([0.8396])  valid accuracy:  tensor([0.8421])
# epoch:  95  train loss:  0.35704609751701355  valid loss:  0.35675233602523804  train_accuracy:  tensor([0.8422])  valid accuracy:  tensor([0.8409])
# epoch:  96  train loss:  0.3583502471446991  valid loss:  0.35752949118614197  train_accuracy:  tensor([0.8411])  valid accuracy:  tensor([0.8389])
# epoch:  97  train loss:  0.35802897810935974  valid loss:  0.35872626304626465  train_accuracy:  tensor([0.8395])  valid accuracy:  tensor([0.8403])
# epoch:  98  train loss:  0.35807374119758606  valid loss:  0.3591039478778839  train_accuracy:  tensor([0.8408])  valid accuracy:  tensor([0.8371])
# epoch:  99  train loss:  0.3590993881225586  valid loss:  0.3556554615497589  train_accuracy:  tensor([0.8386])  valid accuracy:  tensor([0.8460])
# epoch:  100  train loss:  0.35468727350234985  valid loss:  0.35615047812461853  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8401])
# epoch:  101  train loss:  0.35780811309814453  valid loss:  0.3565617799758911  train_accuracy:  tensor([0.8391])  valid accuracy:  tensor([0.8442])
# epoch:  102  train loss:  0.35687851905822754  valid loss:  0.35810792446136475  train_accuracy:  tensor([0.8391])  valid accuracy:  tensor([0.8362])
# epoch:  103  train loss:  0.355267733335495  valid loss:  0.3551115393638611  train_accuracy:  tensor([0.8411])  valid accuracy:  tensor([0.8387])
# epoch:  104  train loss:  0.35534408688545227  valid loss:  0.3566123843193054  train_accuracy:  tensor([0.8392])  valid accuracy:  tensor([0.8432])
# epoch:  105  train loss:  0.3556440472602844  valid loss:  0.3537917137145996  train_accuracy:  tensor([0.8387])  valid accuracy:  tensor([0.8430])
# epoch:  106  train loss:  0.3545134663581848  valid loss:  0.3549618422985077  train_accuracy:  tensor([0.8430])  valid accuracy:  tensor([0.8417])
# epoch:  107  train loss:  0.3562312126159668  valid loss:  0.3546433746814728  train_accuracy:  tensor([0.8404])  valid accuracy:  tensor([0.8452])
# epoch:  108  train loss:  0.35454198718070984  valid loss:  0.35392096638679504  train_accuracy:  tensor([0.8394])  valid accuracy:  tensor([0.8434])
# epoch:  109  train loss:  0.35643768310546875  valid loss:  0.3590620458126068  train_accuracy:  tensor([0.8405])  valid accuracy:  tensor([0.8437])
# epoch:  110  train loss:  0.3560403883457184  valid loss:  0.3550776243209839  train_accuracy:  tensor([0.8373])  valid accuracy:  tensor([0.8436])
# epoch:  111  train loss:  0.3543257415294647  valid loss:  0.349567711353302  train_accuracy:  tensor([0.8388])  valid accuracy:  tensor([0.8418])
# epoch:  112  train loss:  0.355557918548584  valid loss:  0.35322824120521545  train_accuracy:  tensor([0.8395])  valid accuracy:  tensor([0.8366])
# epoch:  113  train loss:  0.3518694043159485  valid loss:  0.35450875759124756  train_accuracy:  tensor([0.8413])  valid accuracy:  tensor([0.8434])
# epoch:  114  train loss:  0.35208773612976074  valid loss:  0.35515663027763367  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8421])
# epoch:  115  train loss:  0.3534700572490692  valid loss:  0.3540119528770447  train_accuracy:  tensor([0.8380])  valid accuracy:  tensor([0.8432])
# epoch:  116  train loss:  0.35179343819618225  valid loss:  0.352838397026062  train_accuracy:  tensor([0.8420])  valid accuracy:  tensor([0.8449])
# epoch:  117  train loss:  0.3530667722225189  valid loss:  0.35167747735977173  train_accuracy:  tensor([0.8395])  valid accuracy:  tensor([0.8459])
# epoch:  118  train loss:  0.3522617518901825  valid loss:  0.3558577001094818  train_accuracy:  tensor([0.8429])  valid accuracy:  tensor([0.8393])
# epoch:  119  train loss:  0.3512004613876343  valid loss:  0.35485899448394775  train_accuracy:  tensor([0.8408])  valid accuracy:  tensor([0.8425])
# epoch:  120  train loss:  0.35266920924186707  valid loss:  0.3564009964466095  train_accuracy:  tensor([0.8412])  valid accuracy:  tensor([0.8398])
# epoch:  121  train loss:  0.35514798760414124  valid loss:  0.35597869753837585  train_accuracy:  tensor([0.8364])  valid accuracy:  tensor([0.8350])
# epoch:  122  train loss:  0.3502846360206604  valid loss:  0.3545685112476349  train_accuracy:  tensor([0.8427])  valid accuracy:  tensor([0.8421])
# epoch:  123  train loss:  0.3504391610622406  valid loss:  0.3520386815071106  train_accuracy:  tensor([0.8429])  valid accuracy:  tensor([0.8460])
# epoch:  124  train loss:  0.3528995215892792  valid loss:  0.357564777135849  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8350])
# epoch:  125  train loss:  0.35060393810272217  valid loss:  0.3542112708091736  train_accuracy:  tensor([0.8424])  valid accuracy:  tensor([0.8428])
# epoch:  126  train loss:  0.3517303168773651  valid loss:  0.3560822308063507  train_accuracy:  tensor([0.8431])  valid accuracy:  tensor([0.8410])
# epoch:  127  train loss:  0.3510810434818268  valid loss:  0.3542078137397766  train_accuracy:  tensor([0.8405])  valid accuracy:  tensor([0.8379])
# epoch:  128  train loss:  0.352905809879303  valid loss:  0.3564401865005493  train_accuracy:  tensor([0.8394])  valid accuracy:  tensor([0.8422])
# epoch:  129  train loss:  0.34980446100234985  valid loss:  0.35384243726730347  train_accuracy:  tensor([0.8423])  valid accuracy:  tensor([0.8429])
# epoch:  130  train loss:  0.35318025946617126  valid loss:  0.3534815013408661  train_accuracy:  tensor([0.8400])  valid accuracy:  tensor([0.8395])
# epoch:  131  train loss:  0.35148346424102783  valid loss:  0.35619327425956726  train_accuracy:  tensor([0.8414])  valid accuracy:  tensor([0.8424])
# epoch:  132  train loss:  0.35175958275794983  valid loss:  0.3553910255432129  train_accuracy:  tensor([0.8400])  valid accuracy:  tensor([0.8425])
# epoch:  133  train loss:  0.3502582907676697  valid loss:  0.3524332344532013  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8397])
# epoch:  134  train loss:  0.3503967821598053  valid loss:  0.35178977251052856  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8449])
# epoch:  135  train loss:  0.35013556480407715  valid loss:  0.3543531894683838  train_accuracy:  tensor([0.8403])  valid accuracy:  tensor([0.8437])
# epoch:  136  train loss:  0.3491385877132416  valid loss:  0.3569170832633972  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8359])
# epoch:  137  train loss:  0.34989026188850403  valid loss:  0.3507300615310669  train_accuracy:  tensor([0.8410])  valid accuracy:  tensor([0.8455])
# epoch:  138  train loss:  0.35117417573928833  valid loss:  0.3552693724632263  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8372])
# epoch:  139  train loss:  0.3505857288837433  valid loss:  0.3532399535179138  train_accuracy:  tensor([0.8411])  valid accuracy:  tensor([0.8375])
# epoch:  140  train loss:  0.35158801078796387  valid loss:  0.3582909405231476  train_accuracy:  tensor([0.8385])  valid accuracy:  tensor([0.8438])
# epoch:  141  train loss:  0.35211798548698425  valid loss:  0.35228410363197327  train_accuracy:  tensor([0.8394])  valid accuracy:  tensor([0.8447])
# epoch:  142  train loss:  0.35214921832084656  valid loss:  0.35574206709861755  train_accuracy:  tensor([0.8397])  valid accuracy:  tensor([0.8360])
# epoch:  143  train loss:  0.3522212505340576  valid loss:  0.35177841782569885  train_accuracy:  tensor([0.8379])  valid accuracy:  tensor([0.8437])
# epoch:  144  train loss:  0.34915223717689514  valid loss:  0.35379526019096375  train_accuracy:  tensor([0.8422])  valid accuracy:  tensor([0.8401])
# epoch:  145  train loss:  0.34987717866897583  valid loss:  0.35192036628723145  train_accuracy:  tensor([0.8403])  valid accuracy:  tensor([0.8393])
# epoch:  146  train loss:  0.350216269493103  valid loss:  0.3573302626609802  train_accuracy:  tensor([0.8406])  valid accuracy:  tensor([0.8422])
# epoch:  147  train loss:  0.34630295634269714  valid loss:  0.35350388288497925  train_accuracy:  tensor([0.8450])  valid accuracy:  tensor([0.8420])
# epoch:  148  train loss:  0.35096436738967896  valid loss:  0.3544226884841919  train_accuracy:  tensor([0.8412])  valid accuracy:  tensor([0.8393])
# epoch:  149  train loss:  0.35118845105171204  valid loss:  0.3560037314891815  train_accuracy:  tensor([0.8380])  valid accuracy:  tensor([0.8399])
# epoch:  150  train loss:  0.34856075048446655  valid loss:  0.35652434825897217  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8429])
# epoch:  151  train loss:  0.34889140725135803  valid loss:  0.35368508100509644  train_accuracy:  tensor([0.8434])  valid accuracy:  tensor([0.8399])
# epoch:  152  train loss:  0.3488657474517822  valid loss:  0.35070207715034485  train_accuracy:  tensor([0.8409])  valid accuracy:  tensor([0.8378])
# epoch:  153  train loss:  0.34690386056900024  valid loss:  0.35295653343200684  train_accuracy:  tensor([0.8424])  valid accuracy:  tensor([0.8378])
# epoch:  154  train loss:  0.3494891822338104  valid loss:  0.3556358218193054  train_accuracy:  tensor([0.8395])  valid accuracy:  tensor([0.8385])
# epoch:  155  train loss:  0.3502243757247925  valid loss:  0.35418766736984253  train_accuracy:  tensor([0.8398])  valid accuracy:  tensor([0.8391])
# epoch:  156  train loss:  0.34715330600738525  valid loss:  0.35334545373916626  train_accuracy:  tensor([0.8424])  valid accuracy:  tensor([0.8416])
# epoch:  157  train loss:  0.3484070897102356  valid loss:  0.3518013656139374  train_accuracy:  tensor([0.8385])  valid accuracy:  tensor([0.8442])
# epoch:  158  train loss:  0.347034215927124  valid loss:  0.35271650552749634  train_accuracy:  tensor([0.8421])  valid accuracy:  tensor([0.8406])
# epoch:  159  train loss:  0.34689390659332275  valid loss:  0.3551623225212097  train_accuracy:  tensor([0.8435])  valid accuracy:  tensor([0.8420])
# epoch:  160  train loss:  0.34501364827156067  valid loss:  0.35663148760795593  train_accuracy:  tensor([0.8457])  valid accuracy:  tensor([0.8390])
# epoch:  161  train loss:  0.347755491733551  valid loss:  0.35269373655319214  train_accuracy:  tensor([0.8400])  valid accuracy:  tensor([0.8432])
# epoch:  162  train loss:  0.3481091260910034  valid loss:  0.3539699614048004  train_accuracy:  tensor([0.8434])  valid accuracy:  tensor([0.8430])
# epoch:  163  train loss:  0.3480610251426697  valid loss:  0.350246787071228  train_accuracy:  tensor([0.8429])  valid accuracy:  tensor([0.8424])
# epoch:  164  train loss:  0.34665948152542114  valid loss:  0.3537634313106537  train_accuracy:  tensor([0.8438])  valid accuracy:  tensor([0.8394])
# epoch:  165  train loss:  0.34769102931022644  valid loss:  0.3509327173233032  train_accuracy:  tensor([0.8440])  valid accuracy:  tensor([0.8487])
# epoch:  166  train loss:  0.34758704900741577  valid loss:  0.35481154918670654  train_accuracy:  tensor([0.8401])  valid accuracy:  tensor([0.8416])
# epoch:  167  train loss:  0.3466806709766388  valid loss:  0.35572436451911926  train_accuracy:  tensor([0.8411])  valid accuracy:  tensor([0.8407])
# epoch:  168  train loss:  0.3459913730621338  valid loss:  0.35531532764434814  train_accuracy:  tensor([0.8461])  valid accuracy:  tensor([0.8413])
# epoch:  169  train loss:  0.3493107259273529  valid loss:  0.35300347208976746  train_accuracy:  tensor([0.8413])  valid accuracy:  tensor([0.8430])
# epoch:  170  train loss:  0.34596335887908936  valid loss:  0.35580068826675415  train_accuracy:  tensor([0.8430])  valid accuracy:  tensor([0.8390])
# epoch:  171  train loss:  0.3485860228538513  valid loss:  0.34997546672821045  train_accuracy:  tensor([0.8406])  valid accuracy:  tensor([0.8484])
# epoch:  172  train loss:  0.3455888032913208  valid loss:  0.35306674242019653  train_accuracy:  tensor([0.8433])  valid accuracy:  tensor([0.8390])
# epoch:  173  train loss:  0.3505040407180786  valid loss:  0.3470829725265503  train_accuracy:  tensor([0.8412])  valid accuracy:  tensor([0.8498])
# epoch:  174  train loss:  0.34751176834106445  valid loss:  0.35225266218185425  train_accuracy:  tensor([0.8428])  valid accuracy:  tensor([0.8394])
# epoch:  175  train loss:  0.34557244181632996  valid loss:  0.3518303334712982  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8444])
# epoch:  176  train loss:  0.3462541699409485  valid loss:  0.35408297181129456  train_accuracy:  tensor([0.8422])  valid accuracy:  tensor([0.8401])
# epoch:  177  train loss:  0.34487050771713257  valid loss:  0.3535172939300537  train_accuracy:  tensor([0.8440])  valid accuracy:  tensor([0.8429])
# epoch:  178  train loss:  0.34782874584198  valid loss:  0.3545401990413666  train_accuracy:  tensor([0.8429])  valid accuracy:  tensor([0.8438])
# epoch:  179  train loss:  0.3469933569431305  valid loss:  0.3526315689086914  train_accuracy:  tensor([0.8416])  valid accuracy:  tensor([0.8403])
# epoch:  180  train loss:  0.3475542664527893  valid loss:  0.350003182888031  train_accuracy:  tensor([0.8408])  valid accuracy:  tensor([0.8448])
# epoch:  181  train loss:  0.3462240695953369  valid loss:  0.35469338297843933  train_accuracy:  tensor([0.8439])  valid accuracy:  tensor([0.8380])
# epoch:  182  train loss:  0.3458619713783264  valid loss:  0.3558942675590515  train_accuracy:  tensor([0.8410])  valid accuracy:  tensor([0.8368])
# epoch:  183  train loss:  0.3454146385192871  valid loss:  0.3536228835582733  train_accuracy:  tensor([0.8440])  valid accuracy:  tensor([0.8444])
# epoch:  184  train loss:  0.3485819101333618  valid loss:  0.35039541125297546  train_accuracy:  tensor([0.8406])  valid accuracy:  tensor([0.8410])
# epoch:  185  train loss:  0.3466978073120117  valid loss:  0.3560228943824768  train_accuracy:  tensor([0.8402])  valid accuracy:  tensor([0.8413])
# epoch:  186  train loss:  0.34496352076530457  valid loss:  0.3534492552280426  train_accuracy:  tensor([0.8421])  valid accuracy:  tensor([0.8429])
# epoch:  187  train loss:  0.3456747233867645  valid loss:  0.3508074879646301  train_accuracy:  tensor([0.8427])  valid accuracy:  tensor([0.8403])
# epoch:  188  train loss:  0.34589695930480957  valid loss:  0.3522205352783203  train_accuracy:  tensor([0.8447])  valid accuracy:  tensor([0.8433])
# epoch:  189  train loss:  0.34489741921424866  valid loss:  0.35593128204345703  train_accuracy:  tensor([0.8420])  valid accuracy:  tensor([0.8441])
# epoch:  190  train loss:  0.3454735279083252  valid loss:  0.35860300064086914  train_accuracy:  tensor([0.8420])  valid accuracy:  tensor([0.8386])
# epoch:  191  train loss:  0.3464200496673584  valid loss:  0.35650375485420227  train_accuracy:  tensor([0.8418])  valid accuracy:  tensor([0.8398])
# epoch:  192  train loss:  0.3435836434364319  valid loss:  0.35582107305526733  train_accuracy:  tensor([0.8444])  valid accuracy:  tensor([0.8407])
# epoch:  193  train loss:  0.3462686538696289  valid loss:  0.3562321066856384  train_accuracy:  tensor([0.8456])  valid accuracy:  tensor([0.8438])
# epoch:  194  train loss:  0.34869781136512756  valid loss:  0.3554042875766754  train_accuracy:  tensor([0.8417])  valid accuracy:  tensor([0.8401])
# epoch:  195  train loss:  0.3440612554550171  valid loss:  0.3558267652988434  train_accuracy:  tensor([0.8422])  valid accuracy:  tensor([0.8410])
# epoch:  196  train loss:  0.3479835093021393  valid loss:  0.3571476936340332  train_accuracy:  tensor([0.8412])  valid accuracy:  tensor([0.8416])
# epoch:  197  train loss:  0.348062127828598  valid loss:  0.3614371418952942  train_accuracy:  tensor([0.8385])  valid accuracy:  tensor([0.8339])
# epoch:  198  train loss:  0.34778717160224915  valid loss:  0.354498952627182  train_accuracy:  tensor([0.8412])  valid accuracy:  tensor([0.8449])
# epoch:  199  train loss:  0.346073716878891  valid loss:  0.3562456965446472  train_accuracy:  tensor([0.8421])  valid accuracy:  tensor([0.8416])

# %%
# Generate a sequence of integers to represent the epoch numbers
epochs = range(num_epoch)

# Plot and label the training and validation loss values
plt.plot(epochs, train_loss_accu, label='Training Loss')
plt.plot(epochs, valid_loss_accu, label='Validation Loss')

# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Set the tick locations
plt.xticks(range(0, num_epoch, 50))
plt.ylim(ymax = 1, ymin = 0)
# Display the plot
plt.legend(loc='best')
plt.show()

# %%
# Generate a sequence of integers to represent the epoch numbers
epochs = range(num_epoch)

# Plot and label the training and validation loss values
plt.plot(epochs, train_accuracy_accu, label='Training accuracy')
plt.plot(epochs, valid_accuracy__accu, label='Validation accuracy')

# Add in a title and axes labels
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Set the tick locations
plt.xticks(range(0, num_epoch, 50))
plt.ylim(ymax = 1, ymin = 0)
# Display the plot
plt.legend(loc='best')
plt.show()
